# %%
# importando pandas e definindo um alias
import pandas as pd

# lendo o arquivo
titanic_df = pd.read_csv('dataset/titanic.csv')

# linhas iniciais
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# verificando a estrutura do arquivo
titanic_df.shape
# Out:
# (891, 12)

# %%
# verificando as linhas do arquivo
titanic_df.shape[0]
# Out:
# 891

# %%
# verificando as colunas do arquivo
titanic_df.shape[1]
# Out:
# 12

# %%
# verificando as últimas linhas do arquivo
titanic_df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# informações estatísticas do arquivo
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# verificando quantos nulos existem em cada coluna do arquivo
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# tirando o percentual de nulos do arquivo e arredondando para 2 casas decimais
round((titanic_df.isnull().sum() * 100) / titanic_df.shape[0],2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
# verificando quem são os sobreviventes / o loc faz esse filtro
titanic_df.loc[titanic_df.Survived >= 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# novo dataframe com apenas homens com mais de  anos
titanic_homens35_df = titanic_df.loc[(titanic_df.Sex == "male") & (titanic_df.Age > 35)]

# %%
titanic_homens35_df
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 13            14         0       3     Andersson, Mr. Anders Johan  male
# 30            31         0       1        Uruchurtu, Don. Manuel E  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 35            36         0       1  Holverson, Mr. Alexander Oskar  male
# ..           ...       ...     ...                             ...   ...
# 845          846         0       3             Abbing, Mr. Anthony  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 860          861         0       3         Hansen, Mr. Claus Peter  male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
# renomeando colunas 
titanic_df = titanic_df.rename(columns = {"Age":"Idade"})

# %%
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex  Idade  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                             Heikkinen, Miss. Laina  female   26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# renomeando colunas
titanic_df = titanic_df.rename(columns = {"PassengerId":"ID Passageiro"})

# %%
titanic_df = titanic_df.rename(columns = {"Survived":"Sobreviventes"})

# %%
titanic_df = titanic_df.rename(columns = {"Pclass":"Classe"})

# %%
titanic_df = titanic_df.rename(columns = {"Name": "Nome"})

# %%
titanic_df = titanic_df.rename(columns = {"Sex":"Gênero"})

# %%
titanic_df = titanic_df.rename(columns = {"Ticket":"Bilhete"})

# %%
titanic_df = titanic_df.rename(columns = {"Fare":"Tarifa"})

# %%
titanic_df = titanic_df.rename(columns = {"Cabin":"Cabine"})

# %%
titanic_df = titanic_df.rename(columns = {"Embarked":"Embarcou"})

# %%
titanic_df.head(3)
# Out:
#    ID Passageiro  Sobreviventes  Classe  \
# 0              1              0       3
# 1              2              1       1
# 2              3              1       3
#
#                                                 Nome  Gênero  Idade  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                             Heikkinen, Miss. Laina  female   26.0      0
#
#    Parch           Bilhete   Tarifa Cabine Embarcou
# 0      0         A/5 21171   7.2500    NaN        S
# 1      0          PC 17599  71.2833    C85        C
# 2      0  STON/O2. 3101282   7.9250    NaN        S

# %%
# criando dataframe com somente as colunas Survived, Pclass, Sex, Age, Ticket, Embarked
novo_titanic_df = titanic_df[['Sobreviventes', 'Classe', 'Gênero', 'Idade', 'Bilhete', 'Embarcou']]

# %%
novo_titanic_df.head(3)
# Out:
#    Sobreviventes  Classe  Gênero  Idade           Bilhete Embarcou
# 0              0       3    male   22.0         A/5 21171        S
# 1              1       1  female   38.0          PC 17599        C
# 2              1       3  female   26.0  STON/O2. 3101282        S

# %%
novo_titanic_df.shape
# Out:
# (891, 6)

# %%
# retornando apenas os dados únicos
titanic_df['Classe'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
# retornando quantidade de valor
titanic_df['Classe'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Classe, dtype: int64

# %%
titanic_df['X'] = 1

# agrupando as informações por classe
titanic_df[['Classe', 'X']].groupby("Classe").sum()
# Out:
#           X
# Classe
# 1       216
# 2       184
# 3       491

# %%
titanic_df['Contador'] = 1

titanic_df[['Idade','Contador']].groupby("Idade").sum()
# Out:
#        Contador
# Idade
# 0.42          1
# 0.67          1
# 0.75          2
# 0.83          2
# 0.92          1
# ...         ...
# 70.00         2
# 70.50         1
# 71.00         2
# 74.00         1
# 80.00         1
#
# [88 rows x 1 columns]
