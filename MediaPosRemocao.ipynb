# %%
# criando a lista de notas
notas = [9,6,7,3,8,8,"oito", "A", "C"]

# removendo os valores indesejados
notas.remove("oito")
notas.remove("A")
notas.remove("C")

# contando quantas posições tem no array
total_notas = len(notas)

# calculando a média
media = print("Sua média é: ", round((sum(notas)/total_notas),2))
# Out:
# Sua média é:  6.83
